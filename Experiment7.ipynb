# %%
#all the colors in set1 but not in set2
set1=set(input("Enter the colors:").split(","))
set2=set(input("Enter the colors:").split(","))
diff=set1-set2
print("The colors in a but not b is:",diff)
# Out:
# Enter the colors:red,maroon,green
# Enter the colors:yellow,purple,maroon
# The colors in a but not b is: {'red', 'green'}

# %%
#all the colors in set1 and set2 combined
set1=set(input("Enter the colors:").split(","))
set2=set(input("Enter the colors:").split(","))
union=set1.union(set2)
print("The colors in set1 and set2 combined is:",union)
# Out:
# Enter the colors:red,green,purple
# Enter the colors:yellow,red
# The colors in set1 and set2 combined is: {'yellow', 'green', 'red', 'purple'}
