# %%
#create list of colors and separate them with comma
colors=input("Enter the colors")
color_list=colors.split(",")
print("The first color is:",color_list[0])
print("The last color is:",color_list[-1])
# Out:
# Enter the colorsred,green,teal
# The first color is: red
# The last color is: teal

# %%
#print extension from file name
filename=input("Enter the filename:")
extension=filename.split(".")[-1]
print("The etension is:",extension)
# Out:
# Enter the filename:exp.ipnyb
# The etension is: ipnyb

# %%
#accept sequence of comma separated numbers from user and generate a list and find sum
number=input("Enter the numbers:")
num2=[int(x) for x in number.split(",")]
print("the list is:",num2)
print("sum of num",sum(num2))
# Out:
# Enter the numbers:1,2,3,4
# the list is: [1, 2, 3, 4]
# sum of num 10
