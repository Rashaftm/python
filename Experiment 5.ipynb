# %%
#third element from the tuple
t=input("enter the elemts:")
print("The elements are:",t)
print("The 2nd element is:",t[1])
print("The 3rd last element is:",t[-3])
# Out:
# enter the elemts:15930
# The elements are: 15930
# The 2nd element is: 5
# The 3rd last element is: 9

# %%
#number separated with commas stored in tuple
number=input("Enter the numbers separated with commas:")
print("The numbers are:",number)
num_t=tuple(int(x) for x in number.split(","))
average=sum(num_t)/len(num_t)
print("The average is:",average)
# Out:
# Enter the numbers separated with commas:7,4,2,8,0,3
# The numbers are: 7,4,2,8,0,3
# The average is: 4.0
