# %%
#Python program to convert Celsius to Fahrenheit
celsius=float(input("Enter the Temperature in Celsius:"))
fahrenheit=celsius*9/5+32
print("Temperature in Fahrenheit:",fahrenheit)
# Out:
# Enter the Temperature in Celsius: 98
# Temperature in Fahrenheit: 208.4

# %%
#Python program to convert kilometers to meters
kilometers=float(input("Enter distance in kilometers:"))
miles=kilometers*0.62137
print("Kilometers in Miles:",miles)
# Out:
# Enter distance in kilometers: 39
# Kilometers in Miles: 24.23343
